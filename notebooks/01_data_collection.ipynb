# %% [markdown]
# # 01. Data Collection & Preprocessing - ForecastBI
# This notebook ingests raw Pakistan Bureau of Statistics (PBS) SPI commodity price data (last 5 years), parses Excel/CSV files, filters the 7 target commodities, handles missing records, and saves the cleaned monthly dataset.

# %%
import pandas as pd
import numpy as np
from pathlib import Path

# Set paths
RAW_PATH = Path('../data/raw')
PROCESSED_PATH = Path('../data/processed')
print('Data paths configured.')

# %% [markdown]
# ## 1. Load Raw PBS Data

# %%
# TODO: Ingest raw files from PBS SPI
# df_raw = pd.read_csv(RAW_PATH / 'dummy_pbs_raw_data.csv')
# df_raw.head()
