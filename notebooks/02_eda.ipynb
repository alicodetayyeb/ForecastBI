# %% [markdown]
# # 02. Exploratory Data Analysis (EDA) - ForecastBI
# Analysis of 5-year price trends, seasonality patterns, inflation spikes, volatility, and cross-commodity correlations across the 7 Pakistani commodities.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from pathlib import Path

PROCESSED_PATH = Path('../data/processed')
FIGURES_PATH = Path('../reports/figures')
print('EDA modules initialized.')

# %% [markdown]
# ## 1. Load Processed Clean Data

# %%
# TODO: Load cleaned data
# df = pd.read_csv(PROCESSED_PATH / 'dummy_clean_commodity_prices.csv')
# df.info()
