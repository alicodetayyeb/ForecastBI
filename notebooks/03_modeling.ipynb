# %% [markdown]
# # 03. Machine Learning Forecasting & Evaluation - ForecastBI
# Train Facebook Prophet and XGBoost models per commodity, perform chronological backtesting, evaluate MAPE/RMSE, and export final 12-month forecasts with confidence intervals for Power BI.

# %%
import pandas as pd
import numpy as np
from pathlib import Path

# Import custom src modules
import sys
sys.path.append('..')
from src.utils import TARGET_COMMODITIES
print(f'Target Commodities: {TARGET_COMMODITIES}')

# %% [markdown]
# ## 1. Train Models & Predict

# %%
# TODO: Run Prophet and XGBoost forecast generation
# ...
